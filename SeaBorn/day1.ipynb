# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\chitr\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\chitr\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\chitr\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")
type(iris)
# Out:
# pandas.DataFrame

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include=object)
# Out:
# C:\Users\chitr\AppData\Local\Temp\ipykernel_9140\3519016943.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   iris.describe(include=object)
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %%
iris["species"].unique()
# Out:
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
sns.histplot(iris["petal_length"], bins=20)
plt.show()

# %%
##kde - kernel density plot

# %%
sns.kdeplot(iris["petal_length"])
plt.show()

##this data has two modes and its called twomodel

# %%
sns.scatterplot(x=iris["petal_length"],y=iris["petal_width"])
plt.show()

# %%
sns.scatterplot(x="petal_length",y="petal_width",  data=iris, hue="species")
plt.show()

###this is an exampleof multiple plots on same axis

# %%
setosa = iris[iris['species'] == 'setosa']
versicolor = iris[iris['species'] == 'versicolor']
virginica = iris[iris['species'] == 'virginica']

plt.scatter(x=setosa['petal_length'],
            y=setosa['petal_width'],
            c='blue')

plt.scatter(x=versicolor['petal_length'],
            y=versicolor['petal_width'],
            c='orange')

plt.scatter(x=virginica['petal_length'],
            y=virginica['petal_width'],
            c='green')

plt.show()

# %%
sns.jointplot(x="petal_length", y="petal_width", data=iris, kind="reg")
plt.show()

# %%
sns.jointplot(x="petal_length", y="petal_width", data=iris, kind="kde", hue="species")
plt.show()

# %%
sns.jointplot(x="petal_length", y="petal_width", data=iris, hue="species")
plt.show()

# %%
sns.pairplot(data=iris, hue="species")
plt.show()

# %%
sns.countplot(x="species", data=iris, hue="species")
plt.show()

# %%
sns.boxplot(x="species", y="sepal_length", data=iris)
plt.show()

###o is outlier here is not considered

# %%
sns.violinplot(x="species", y="sepal_length", data=iris)
plt.show()

# %%
##how to plot corelation

iris.corr(numeric_only=True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(numeric_only=True), cmap="Blues")
# Out:
# <Axes: >

# %%
###using the right visualisation/plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
##1d view.. one variable ---distribution(numenrical (hist, kde, boxplot)), categorical(counts)(barplot, countplot)
##2d view  two variable ---num-num(scatter), cat-cat(barplt, boxplot, violin)
##2d with multiple variable -- pairplot, histplot
###muli-deminsion plot--scatter plot with hue(with color coding), num-num-categorical, surface  plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1D

# %%
sns.histplot(iris["sepal_length"], bins=10)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
setosa = iris.loc[iris["species"] == "setosa"]
sns.boxplot(y="sepal_length", data=setosa)
# Out:
# <Axes: ylabel='sepal_length'>

# %%
sns.countplot(x="species", data=iris)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
n_setosa = iris[iris['species'] == 'setosa'].shape[0]
n_versicolor = iris[iris['species'] == 'versicolor'].shape[0]
n_virginica = iris[iris['species'] == 'virginica'].shape[0]

data = [n_setosa, n_versicolor, n_virginica]
labels = ['setosa', 'versicolor', 'virginia']

plt.pie(
    data,
    labels=labels,
    autopct='%.0f%%'   # To show the percentages in tags
)

plt.show()

# %% [markdown]
# ### 2d plot

# %%
sns.scatterplot(x="petal_length", y="petal_width", data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.lineplot(x="petal_length", y="petal_width", data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.boxplot(x="species", y="sepal_length", data=iris) ##one is numerical, one categotical data
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.scatterplot(x="petal_length", y="petal_width", data=iris, hue="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
##categorical data ex--sex
sns.countplot(x=tips["sex"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, str): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.countplot(x="day", data=tips, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# ### two categprical and one data

# %%
##day, time --categorical, totalbill-numerical
sns.barplot(x="day", y="total_bill", hue="time", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##titanic dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import ArtistAnimation

# %%
class CoinTossSequence:
    def __int__(self, p_h = 0.5, num_tosses = 100):
        self.p_h = p_h
        self.num_tosses = num_tosses
        self.animate_coin_toss_sequence()

    def toss_coin(self):
        all_tosses = []
        cumulative = [0]
        for toss_id in range(self.num_tosses):
            toss_value = np.random.choice(a=[0,1], p=[1-self.p_h, self.p_h]) 
            all_tosses.append(toss_value)
            cumulative.append(cumulative[toss_id]+toss_value)
        cumulative = cumulative[1:]
        cumulative = [val/(i+1) for i,val in enumerate(cumulative)]
        return np.array(all_tosses),np.array(cumulative)
        
    def animate_coin_toss_sequence(self):
        artist = []
        fig, ax = plt.subplots()
        ax.set_ylim(0,1)
        all_tosses, cumulative = self.toss_coin()
        for i,_ in enumerate(cumulative):
            c = cumulative[0:i]
            line = ax.plot(c, c = "c")
            hline = ax.axline(y=self.p_h, c="y", linestyle = "--")
            artists.append([line[0], hline])
        anim  = ArtistAnimation(fig, artists, interval)

# %%
class CoinTossSequence:
  def __init__(self,p_h=0.5,num_tosses=100):
    self.p_h = p_h # probab of head
    self.num_tosses = num_tosses  # no of tosses
    self.animate_coin_toss_sequence()

  def toss_coin(self):
    all_tosses = []
    cumulative = [0]
    for toss_id in range(self.num_tosses):
      toss_value = np.random.choice(a=[0,1],p=[1-self.p_h,self.p_h])
      all_tosses.append(toss_value)
      cumulative.append(cumulative[toss_id]+toss_value)
    cumulative =  cumulative[1:]
    cumulative = [val/(i+1) for i,val in enumerate(cumulative)]
    return np.array(all_tosses),np.array(cumulative)
  

  def animate_coin_toss_sequence(self):
    artists = []

    fig, ax = plt.subplots()

    ax.set_xlim(0, self.num_tosses)
    ax.set_ylim(0, 1)

    all_tosses, cumulative = self.toss_coin()

    for i in range(len(cumulative)):
        line = ax.plot(cumulative[:i+1], color="c")
        hline = ax.axhline(y=self.p_h, color="y", linestyle="--")
        artists.append([line[0], hline])

    anim = ArtistAnimation(fig, artists, interval=100, blit=True)
    anim.save("coin.gif", fps=10)

if __name__ == "__main__":
  coin = CoinTossSequence(p_h=0.8,num_tosses=100)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import ArtistAnimation

class CoinTossSequence:
    def __init__(self, p_h=0.5, num_tosses=100):
        self.p_h = p_h  # probability of head
        self.num_tosses = num_tosses  # no of tosses
        self.animate_coin_toss_sequence()

    def toss_coin(self):
        all_tosses = []
        cumulative = [0]
        for toss_id in range(self.num_tosses):
            toss_value = np.random.choice(a=[0, 1], p=[1-self.p_h, self.p_h])
            all_tosses.append(toss_value)
            cumulative.append(cumulative[toss_id] + toss_value)
        cumulative = cumulative[1:]
        cumulative = [val / (i + 1) for i, val in enumerate(cumulative)]
        return np.array(all_tosses), np.array(cumulative)

    def animate_coin_toss_sequence(self):
        artists = []

        fig, ax = plt.subplots()
        ax.set_xlim(0, self.num_tosses)
        ax.set_ylim(0, 1)

        # 1. FIX: axhline ko loop se bahar nikaal diya (yeh background me constant rahegi)
        ax.axhline(y=self.p_h, color="y", linestyle="--")

        all_tosses, cumulative = self.toss_coin()

        for i in range(len(cumulative)):
            # 2. FIX: Har frame ke liye sirf badalti hui line plot hogi
            line = ax.plot(cumulative[:i+1], color="c")
            artists.append([line[0]])

        # 3. FIX: writer='pillow' add kiya taaki GIF smoothly save ho
        anim = ArtistAnimation(fig, artists, interval=100, blit=True)
        anim.save("coin.gif", writer='pillow', fps=10)
        
        # 4. FIX: Notebook me static image ko pop-up hone se rokne ke liye
        plt.close(fig)
        print("GIF successfully save ho gayi hai 'coin.gif' naam se!")

if __name__ == "__main__":
    coin = CoinTossSequence(p_h=0.8, num_tosses=100)
# Out:
# GIF successfully save ho gayi hai 'coin.gif' naam se!

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import ArtistAnimation

class DiceRollAnimation:
    def __init__(self, num_rolls=150):
        self.num_rolls = num_rolls  # Total kitni baar dice fekna hai
        self.animate_dice()

    def simulate_rolls(self):
        # 1 se 6 tak random numbers generate karega
        return np.random.randint(1, 7, size=self.num_rolls)

    def animate_dice(self):
        artists = []
        fig, ax = plt.subplots(figsize=(6, 5))

        # Graph ke corners lock kar dete hain taaki animation hile na
        ax.set_xlim(0.5, 6.5)
        ax.set_ylim(0, self.num_rolls // 4)  # Ek safe height estimate
        ax.set_xticks(range(1, 7))

        all_rolls = self.simulate_rolls()

        # Frame-by-frame bars ko build karenge
        for i in range(1, len(all_rolls) + 1):
            # Har frame me ek naya roll add hoga
            current_rolls = all_rolls[:i]
            counts = np.bincount(current_rolls, minlength=7)[1:]

            # Bar plot banana (wahi same cyan color aur size)
            bars = ax.bar(range(1, 7), counts, color="c", width=0.4)
            
            # Matplotlib me bar container ko list me badal kar artists me dalna hota hai
            artists.append(list(bars))

        # GIF save karne ka chakkar
        anim = ArtistAnimation(fig, artists, interval=50, blit=True)
        anim.save("dice_roll.gif", writer='pillow', fps=20)
        
        plt.close(fig)
        print("Bhai, 'dice_roll.gif' ready hai! Jaakar folder check kar.")

if __name__ == "__main__":
    # 150 rolls ka mast animation banega
    DiceRollAnimation(num_rolls=150)
# Out:
# Bhai, 'dice_roll.gif' ready hai! Jaakar folder check kar.
