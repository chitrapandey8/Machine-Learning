# %%
import math

# %% [markdown]
# ### Maths

# %%
# ##logarithm
# 2^3 = 8
# we can rewrite: 2 ki power esi kya rakhu ki 8 aajaye. 
# log of 8 base 2 = 3
# log of 16 base 4  =2
# log of 100 base 10 = 2

# e is natural base

# %%
math.log(10)
# math.log(100,10)
# Out:
# 2.302585092994046

# %%
math.gcd(15,10)
math.gcd(2,10)
math.gcd(13,17)

# (a, b) = (b%a, a)
# Out:
# 1

# %%
a = int(input())
b = int(input())

while a != 0:
    a,b = b%a,a


print(b)
# Out:
# 2

# %%
math.lcm(15,10,15)
# Out:
# 30

# %%
##check prime:

# N = 40 (1,2,4,5,8,10,20,40) ##all divisors of a no appearn in pair
# root n * root n = N
# maxx of n will be root(n)


# N = 40    1,2,4,5||,8,10,20,40 -- two groups

# so we reduce our search space we only check till root no becoz if we do not find a factor in between rootn then we will not find after root n

# %%
n = int(input())
def isPrime(n):

    q = int(math.sqrt(n))
    for i in range(2,q+1):
        if n %i == 0:
            return False;

    return True;


print(isPrime(n))
# Out:
# False

# %%
##10 ki power 8 interations in 1 sec

# %%
# ##Ap
# #3,7,11,15,19,23 this has a constant diff of d = 4
# T(n) = a + (n-1)*d;
# T(6) = 3 + (6-1)*4
#      = 23

# ##sum till n terms
# Sn = n/2[2a+(n-1)*d] -- n is nth term

# %%
##GP:
a = first term
r = commom ratio

3,6,12,24,48
a = 3, r = 2

##to find the nth term of gp:
T(n) = ar^n-1 == 3*2^6-1 
    = 96


##sum of n terms of GP:
S(n) = a(r^n -1)/r-1
     = 3(2^3 -1)/2-1
     = 3(8-1)
     = 21
