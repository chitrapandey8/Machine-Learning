# %%
class acc:
    next_id = 0
    def __init__(self, openbalance = 0):
        acc.next_id += 1
        self.id = acc.next_id
        self.__balance = openbalance ## __ makesa attributr private which cannot be aceesssed
        self.num_transactions = 0
        self.max_transactions = 5

    def des(self):
        print(f"acc: {self.id}, bal: {self.__balance}" )    
    
    def desposit(self,amount):
        if amount>=0 and self.num_transactions < self.max_transactions:
            self.__balance += amount
            self.num_transactions += 1

    def Withdraw(self, amount):
        if amount >= 0 and self.__balance >= amount and self.num_transactions < self.max_transactions:
            self.__balance -= amount 
            self.num_transactions += 1

    
    def __str__(self):
        return f"{self.id} {self.balance}"

    def __regr__(self):
        return {self.id}

# %% [markdown]
# ## Polymorphism

# %%
class SavingsAcc(acc):
    pass

# %%
class CurrentAcc(acc):
    def __init__(self, openbalance=0): ##it call init of parent class then go further
        super().__init__(openbalance)  
        self.max_transactions = 10 ##Parent ki max_transaction leke update kar diya

# %%
sav = SavingsAcc()
curr = CurrentAcc()

sav.desposit(100)
sav.Withdraw(50)
sav.desposit(100)
sav.des()

sav.balance = 10000000 ##this should happen , only can be chaged thorugh function
sav.des()
# Out:
# acc: 9, bal: 150
# acc: 9, bal: 150

# %%
class acc:
    next_id = 0
    def __init__(self, openbalance = 0):
        acc.next_id += 1
        self.id = acc.next_id
        self.balance = openbalance ## __ makesa attributr private which cannot be aceesssed, private varivnle dosnot get inherited
        self.num_transactions = 0
        self.max_transactions = 5

    def des(self):
        print(f"acc: {self.id}, bal: {self.balance}" )    
    
    def desposit(self,amount):
        if amount>=0 and self.num_transactions < self.max_transactions:
            self.balance += amount
            self.num_transactions += 1

    def Withdraw(self, amount):
        if amount >= 0 and self.balance >= amount and self.num_transactions < self.max_transactions:
            self.balance -= amount 
            self.num_transactions += 1

    
    def __str__(self):
        return f"{self.id} {self.balance}"

    def __regr__(self):
        return {self.id}  


class SavingsAcc(acc):
    def __int__(self):
        super().__init__()
        

    def get_interest(self):
        return self.balance*0.3


class CurrentAcc(acc):
    def __init__(self, openbalance=0): ##it call init of parent class then go further
        super().__init__(openbalance)  
        self.max_transactions = 10 ##Parent ki max_transaction leke update kar diya
    
    def get_interest(self):
        return 0
    

sav = SavingsAcc()
curr = CurrentAcc()

# %%
sav.desposit(100)
curr.desposit(100)

# %%
print(sav)
sav.get_interest()
# Out:
# 1 100
# 30.0

# %% [markdown]
# ## Exception

# %%
import math ##imported as a object, functions are meths in this math module 

print(type(math))

math.pi
# Out:
# <class 'module'>
# 3.141592653589793

# %%
##how to cehck all functions in math module

help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
import random

# %%
random.randint(1,10)
# Out:
# 3

# %%
random.seed(100) ###makes time constant, so output of random is static
random.randint(1,100)
##pesuod random behaviour
# Out:
# 19

# %%
import os
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# MODULE REFERENCE
#     https://docs.python.org/3.14/library/os#module-os
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
# ...

# %%
##current working dirrectoru (folder)
os.getcwd()
# Out:
# 'd:\\ML\\Python\\Week3'

# %%
os.mkdir("hello") ##cretaing directory

# %%
os.listdir() ##listalldirectory
# Out:
# ['Day1.ipynb', 'Day2.ipynb', 'Day3.ipynb', 'Day4.ipynb', 'image.png']

# %%
##pathlib
import pathlib

# %%
path = pathlib.Path('/')
# Out:
# False

# %%
path.cwd() ##current working directory
# Out:
# WindowsPath('d:/ML/Python/Week3')

# %%
path

# %%
def hello():
    ''' hello  ur
    
    '''
    return "hello"

# %%
hello()
help(hello)
# Out:
# Help on function hello in module __main__:
#
# hello()
#     hello  ur

# %%
hello?
# Out:
# Signature: hello()
# Docstring:
# hello  ur
#
#
# File:      c:\users\chitr\appdata\local\temp\ipykernel_9600\3737060723.py
# Type:      function

# %%
nth_sqrt = math.sqrt ##functions can be stored they  are first class citizens
nth_sqrt(2)
# Out:
# 1.4142135623730951

# %%
m = math ##start refereing to math module
m.sqrt(2)
# Out:
# 1.4142135623730951

# %%
##popular alias
# np - numpy
# pd - pandas
# plt - mathplotlib.pylot


##creting alias
import math as m
m.sqrt(2)
# Out:
# 1.4142135623730951

# %%
m.pi
# Out:
# 3.141592653589793

# %%
from math import pi, sqrt
pi
sqrt(2)
# Out:
# 1.4142135623730951

# %%
from math import * ##import import everthing

# %%
# module is libarary

# %% [markdown]
# # Exception Handling

# %%
##Complile error --- syntatitical error
##logical error 
##runtime error --most error in python is runtime error --syntax error, name error, value error, out of index eror,

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
"hello".sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 "hello".sort()
#       2
#
# AttributeError: 'str' object has no attribute 'sort'

# %%
__builtins__

temp = dir(__builtins__)

cnt = 0
for ele in temp:
    if "Error" in ele:
        cnt += 1
        print(ele)


print(cnt)
# Out:
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# BufferError
# ChildProcessError
# ConnectionAbortedError
# ConnectionError
# ConnectionRefusedError
# ConnectionResetError
# EOFError
# EnvironmentError
# FileExistsError
# FileNotFoundError
# FloatingPointError
# IOError
# ImportError
# IndentationError
# IndexError
# InterruptedError
# IsADirectoryError
# KeyError
# LookupError
# MemoryError
# ModuleNotFoundError
# NameError
# NotADirectoryError
# NotImplementedError
# OSError
# OverflowError
# PermissionError
# ProcessLookupError
# PythonFinalizationError
# RecursionError
# ReferenceError
# RuntimeError
# SyntaxError
# SystemError
# TabError
# TimeoutError
# TypeError
# UnboundLocalError
# UnicodeDecodeError
# UnicodeEncodeError
# UnicodeError
# UnicodeTranslateError
# ValueError
# WindowsError
# ZeroDivisionError
# _IncompleteInputError
# 51

# %%
a = int(input("a"))
b = int(input("b"))

try:
    resutt = a/b
    print(f"Output is {resutt}")
except:
    print("this is error")
# Out:
# this is error

# %%
##HAndling diferent kind of eeror
lst = [2,0,"hello",None]

for ele in lst:
    try:
        print(F"{ele}")
        result = 4/ele
        print(f"{result}")
    except Exception as e: ##catches the type of error  
        print(e)
# Out:
# 2
# 2.0
# 0
# division by zero
# hello
# unsupported operand type(s) for /: 'int' and 'str'
# None
# unsupported operand type(s) for /: 'int' and 'NoneType'

# %%
for ele in lst:
    try:
        print(F"{ele}")
        result = 4/ele
        print(f"{result}")
    except ValueError as va: ##catches the type of error  
        print(va)  
    except ZeroDivisionError as zero: ##catches the type of error  
        print("provide no gretaer then zero",zero)  
    except Exception as e: ##catches the type of error  
        print(e,"acha")  
    finally:
        print("Done!!")
# Out:
# 2
# 2.0
# Done!!
# 0
# provide no gretaer then zero division by zero
# Done!!
# hello
# unsupported operand type(s) for /: 'int' and 'str' acha
# Done!!
# None
# unsupported operand type(s) for /: 'int' and 'NoneType' acha
# Done!!

# %%
##custom Expection
try:
    name = input("enter name")

    if len(name) < 3:
        raise Exception("shoul be gretertheb 3")
    print(name)
except Exception as e:
    print(e)
# Out:
# shoul be gretertheb 3
