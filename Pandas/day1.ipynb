# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("gapminder_data_graphs.csv") ##stores in tabular structure
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
type(df["country"])
##dataframe is matrix
##series id 1d, datafrma is stack of mulitple series
# Out:
# pandas.Series

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3675 entries, 0 to 3674
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      3675 non-null   str
#  1   continent    3675 non-null   str
#  2   year         3675 non-null   int64
#  3   life_exp     3675 non-null   float64
#  4   hdi_index    3563 non-null   float64
#  5   co2_consump  3671 non-null   float64
#  6   gdp          3633 non-null   float64
#  7   services     3675 non-null   float64
# dtypes: float64(5), int64(1), str(2)
# memory usage: 229.8 KB

# %%
##to print top five rows
df.head(10)
##to print bottom rows
df.tail()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3670  Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671  Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672  Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673  Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674  Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# 3674      27.2

# %%
df.describe()
# Out:
#               year     life_exp    hdi_index  co2_consump            gdp  \
# count  3675.000000  3675.000000  3563.000000  3671.000000    3633.000000
# mean   2008.000000    69.849306     0.674864     4.712731   11966.053675
# std       6.056125     8.886563     0.164834     6.567435   17105.787953
# min    1998.000000    32.500000     0.255000     0.015900     238.000000
# 25%    2003.000000    63.900000     0.537500     0.560500    1470.000000
# 50%    2008.000000    71.700000     0.699000     2.250000    4280.000000
# 75%    2013.000000    76.400000     0.805000     6.615000   13600.000000
# max    2018.000000    84.800000     0.956000    67.100000  105000.000000
#
#           services
# count  3675.000000
# mean     51.248705
# std      18.312501
# min       5.590000
# 25%      37.600000
# 50%      52.900000
# 75%      65.700000
# max      88.500000

# %%
df.describe(include="object")
# Out:
# C:\Users\chitr\AppData\Local\Temp\ipykernel_11164\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#             country continent
# count          3675      3675
# unique          175         6
# top     Afghanistan    Africa
# freq             21      1071

# %%
#list of columns
df.columns
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='str')

# %%
df.keys() ##pandas is specialised dictionary
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='str')

# %%
df[["country", "continent"]]
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 3670     Zimbabwe    Africa
# 3671     Zimbabwe    Africa
# 3672     Zimbabwe    Africa
# 3673     Zimbabwe    Africa
# 3674     Zimbabwe    Africa
#
# [3675 rows x 2 columns]

# %%
##To list all unique contries
df["country"].unique
# Out:
# <bound method Series.unique of 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: str>

# %%
df["country"].value_counts()
df["country"].value_counts().index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        ...
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='str', name='country', length=175)

# %%
##rename a columns
df.rename({"country":"Country"},axis=1,inplace=1)

# %%
df
# Out:
#      continent  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0         Asia  1998      53.3      0.344       0.0522     NaN      24.4
# 1         Asia  1999      54.7      0.348       0.0402     NaN      24.6
# 2         Asia  2000      54.7      0.350       0.0370     NaN      24.7
# 3         Asia  2001      54.8      0.353       0.0376     NaN      24.7
# 4         Asia  2002      55.5      0.384       0.0471   333.0      25.6
# ...        ...   ...       ...        ...          ...     ...       ...
# 3670    Africa  2014      58.0      0.547       0.8810  1440.0      25.4
# 3671    Africa  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672    Africa  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673    Africa  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674    Africa  2018      60.6      0.569       0.8500  1510.0      27.2
#
#        Total
# 0     2051.3
# 1     2053.7
# 2     2054.7
# 3     2055.8
# 4     2057.5
# ...

# %%
df.Country ##way of accesing not recomeed
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: Country, Length: 3675, dtype: str

# %%
# ##how to drop a perticular column
# df.drop("Country",axis=1, inplace=True)
# df

# %%
df["Total"] = df["year"] + df["life_exp"]

# %%
df
# Out:
#      continent  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0         Asia  1998      53.3      0.344       0.0522     NaN      24.4
# 1         Asia  1999      54.7      0.348       0.0402     NaN      24.6
# 2         Asia  2000      54.7      0.350       0.0370     NaN      24.7
# 3         Asia  2001      54.8      0.353       0.0376     NaN      24.7
# 4         Asia  2002      55.5      0.384       0.0471   333.0      25.6
# ...        ...   ...       ...        ...          ...     ...       ...
# 3670    Africa  2014      58.0      0.547       0.8810  1440.0      25.4
# 3671    Africa  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672    Africa  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673    Africa  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674    Africa  2018      60.6      0.569       0.8500  1510.0      27.2
#
#        Total
# 0     2051.3
# 1     2053.7
# 2     2054.7
# 3     2055.8
# 4     2057.5
# ...

# %%
##Row -- operations
se = df["year"]
se
# Out:
# 0       1998
# 1       1999
# 2       2000
# 3       2001
# 4       2002
#         ...
# 3670    2014
# 3671    2015
# 3672    2016
# 3673    2017
# 3674    2018
# Name: year, Length: 3675, dtype: int64

# %%
##to get 6th row
se[2:4]
# Out:
# 2    2000
# 3    2001
# Name: year, dtype: int64

# %%
se.index = np.arange(1,df.shape[0]+1,1) ##changed the indexx
se
# Out:
# 1       1998
# 2       1999
# 3       2000
# 4       2001
# 5       2002
#         ...
# 3671    2014
# 3672    2015
# 3673    2016
# 3674    2017
# 3675    2018
# Name: year, Length: 3675, dtype: int64

# %%
##implicet index are already present for example 0,1,2,3,4,5..
##explicet index are given from outside

# %%
data = pd.Series(["a","b","c"], index= [1,2,3])
data
# Out:
# 1    a
# 2    b
# 3    c
# dtype: str

# %%
data[1] ##uses explicit indexing
# Out:
# 'a'

# %%
data[1:] ##slicing used implicit indexing
# Out:
# 2    b
# 3    c
# dtype: str

# %%
##loc-- works with explicit indexes/labels
##iloc--works with implicit indesed/positional indexes

df.loc[[1,10,100]]
# Out:
#          Country      continent  year  life_exp  hdi_index  co2_consump  \
# 1    Afghanistan           Asia  1999      54.7      0.348       0.0402
# 10   Afghanistan           Asia  2008      59.2      0.447       0.1520
# 100    Argentina  South America  2014      76.5      0.836       4.5600
#
#          gdp  services   Total
# 1        NaN      24.6  2053.7
# 10     415.0      28.2  2067.2
# 100  13600.0      75.3  2090.5

# %%
df.iloc[-1]  ##inpyhon -1 iss
# Out:
# Country        Zimbabwe
# continent        Africa
# year               2018
# life_exp           60.6
# hdi_index         0.569
# co2_consump        0.85
# gdp              1510.0
# services           27.2
# Total            2078.6
# Name: 3674, dtype: object

# %%
temp = df.set_index("year") ##setting year as label

# %%
temp
# Out:
#           Country continent  life_exp  hdi_index  co2_consump     gdp  \
# year
# 1998  Afghanistan      Asia      53.3      0.344       0.0522     NaN
# 1999  Afghanistan      Asia      54.7      0.348       0.0402     NaN
# 2000  Afghanistan      Asia      54.7      0.350       0.0370     NaN
# 2001  Afghanistan      Asia      54.8      0.353       0.0376     NaN
# 2002  Afghanistan      Asia      55.5      0.384       0.0471   333.0
# ...           ...       ...       ...        ...          ...     ...
# 2014     Zimbabwe    Africa      58.0      0.547       0.8810  1440.0
# 2015     Zimbabwe    Africa      58.6      0.553       0.8810  1450.0
# 2016     Zimbabwe    Africa      59.2      0.558       0.7710  1430.0
# 2017     Zimbabwe    Africa      59.9      0.563       0.8450  1480.0
# 2018     Zimbabwe    Africa      60.6      0.569       0.8500  1510.0
#
#       services   Total
# year
# 1998      24.4  2051.3
# 1999      24.6  2053.7
# 2000      24.7  2054.7
# ...

# %%
temp["gdp"]
# Out:
# year
# 1998       NaN
# 1999       NaN
# 2000       NaN
# 2001       NaN
# 2002     333.0
#          ...
# 2014    1440.0
# 2015    1450.0
# 2016    1430.0
# 2017    1480.0
# 2018    1510.0
# Name: gdp, Length: 3675, dtype: float64

# %%
d = {"Country":"India","year":2009, "life_exp":37.08, "continent":"Asia", "gdp":100}

# %%
df =pd.concat([df,pd.DataFrame([d])], ignore_index = True)

# %%
df ##pd.concar([df,pd.dataframe([d])])
# Out:
#           Country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998     53.30      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999     54.70      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000     54.70      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001     54.80      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002     55.50      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3671     Zimbabwe    Africa  2015     58.60      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016     59.20      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017     59.90      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018     60.60      0.569       0.8500  1510.0
# 3675        India      Asia  2009     37.08        NaN          NaN   100.0
#
#       services   Total
# 0         24.4  2051.3
# ...

# %%
df.loc[len(df.index)] = [
    "India",
    2025,
    70.5,
    0.75,
    2.5,
    3000,
    55.2,
    3677,
    "Asia"
]

# %%
df
# Out:
#           Country continent    year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998.0     53.30      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999.0     54.70      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000.0     54.70      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001.0     54.80      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002.0     55.50      0.384       0.0471   333.0
# ...           ...       ...     ...       ...        ...          ...     ...
# 3672     Zimbabwe    Africa  2016.0     59.20      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017.0     59.90      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018.0     60.60      0.569       0.8500  1510.0
# 3675        India      Asia  2009.0     37.08        NaN          NaN   100.0
# 3676        India      2025    70.5      0.75      2.500    3000.0000    55.2
#
#       services   Total
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3672    False
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# Length: 3677, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, continent, year, life_exp, hdi_index, co2_consump, gdp, services, Total]
# Index: []

# %%
##drop a row with label
df.drop(1,axis = 0,inplace=True)

# %%
df.iloc[1]
# Out:
# Country        Afghanistan
# continent             Asia
# year                1999.0
# life_exp              54.7
# hdi_index            0.348
# co2_consump         0.0402
# gdp                    NaN
# services              24.6
# Total               2053.7
# Name: 1, dtype: object

# %%
df.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2761, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2761 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.iloc[1:5,0:4] ##uapr +1 kar diye the na
# Out:
#        Country continent    year  life_exp
# 2  Afghanistan      Asia  2000.0      54.7
# 3  Afghanistan      Asia  2001.0      54.8
# 4  Afghanistan      Asia  2002.0      55.5
# 5  Afghanistan      Asia  2003.0      56.5

# %%
df.loc[1:5,0:4] ##actual columns are counteyr.................
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.loc[1:5,0:4]
#
# File c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1395, in _LocIndexer._getitem_tuple(self, tup)
#    1392 if self._multi_take_opportunity(tup):
#    1393     return self._multi_take(tup)
# -> 1395 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.loc[1:5,"year":"life_exp"]
# Out:
#      year  life_exp
# 2  2000.0      54.7
# 3  2001.0      54.8
# 4  2002.0      55.5
# 5  2003.0      56.5

# %%
df["life_exp"].mean()
# Out:
# np.float64(69.82571545157779)

# %%
df["life_exp"].sum()
# Out:
# np.float64(256679.33)

# %%
df.sort_values(["year"],ascending=False)
# Out:
#             Country continent    year  life_exp  hdi_index  co2_consump  \
# 1385  Guinea-Bissau    Africa  2018.0     60.30      0.472       0.1810
# 3653         Zambia    Africa  2018.0     62.50      0.582       0.3020
# 3611        Vietnam      Asia  2018.0     74.30      0.700       2.1600
# 3674       Zimbabwe    Africa  2018.0     60.60      0.569       0.8500
# 41          Albania    Europe  2018.0     78.40      0.792       1.5900
# ...             ...       ...     ...       ...        ...          ...
# 3612          Yemen      Asia  1998.0     62.50      0.431       0.7340
# 3633         Zambia    Africa  1998.0     45.50      0.416       0.2310
# 0       Afghanistan      Asia  1998.0     53.30      0.344       0.0522
# 21          Albania    Europe  1998.0     74.80      0.655       0.5630
# 3676          India      2025    70.5      0.75      2.500    3000.0000
#
#          gdp  services   Total
# 1385   638.0      30.3  2078.3
# 3653  1370.0      39.3  2080.5
# ...

# %%
df.sort_values(["year","life_exp"],ascending=[False, True])
# Out:
#                        Country continent    year  life_exp  hdi_index  \
# 1889                   Lesotho    Africa  2018.0     51.40      0.522
# 650   Central African Republic    Africa  2018.0     51.50      0.395
# 1112                  Eswatini    Africa  2018.0     57.80      0.605
# 2267                Mozambique    Africa  2018.0     57.90      0.452
# 2981           Solomon Islands   Oceania  2018.0     59.00      0.564
# ...                        ...       ...     ...       ...        ...
# 1449          Hong Kong, China      Asia  1998.0     79.60      0.820
# 3171                    Sweden    Europe  1998.0     79.60      0.894
# 3192               Switzerland    Europe  1998.0     79.90      0.882
# 1680                     Japan      Asia  1998.0     81.00      0.849
# 3676                     India      2025    70.5      0.75      2.500
#
#       co2_consump      gdp  services   Total
# 1889       1.2600   1110.0      41.6  2069.4
# ...

# %%
##how to create dataframe from scratch

pd.Series([10,20,30], index=["a","b","c"])
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
##row oriented
pd.DataFrame([[10,20],[30,40]], columns=["A","B"], index=["h","h"])
# Out:
#     A   B
# h  10  20
# h  30  40

# %%
pd.DataFrame({"A":[10,20], "B":[20,40]}) ###keys in datafrmas are columns
# Out:
#     A   B
# 0  10  20
# 1  20  40

# %%
pd.Series(["A","B"], index= ["a","b"])
# Out:
# a    A
# b    B
# dtype: str
