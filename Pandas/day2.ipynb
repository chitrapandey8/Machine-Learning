# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("movies.csv")
df1= pd.read_csv("directors.csv")

# %%
df
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
df["Actors"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
a = pd.DataFrame([["A","B"],["A","B"]], columns=["a","b"])
b = pd.DataFrame([["A","B"],["A","B"]], columns=["a","c"])

# %%
pd.concat((a,b), axis=0)
# Out:
#    a    b    c
# 0  A    B  NaN
# 1  A    B  NaN
# 0  A  NaN    B
# 1  A  NaN    B

# %%
a
# Out:
#    a  b
# 0  A  B
# 1  A  B

# %%
b
# Out:
#    a  c
# 0  A  B
# 1  A  B

# %%
pd.concat([a,b],keys=["x","y"])
# Out:
#      a    b    c
# x 0  A    B  NaN
#   1  A    B  NaN
# y 0  A  NaN    B
#   1  A  NaN    B

# %%
##inner concatenation
pd.concat([a,b], axis=0, join="inner")
# Out:
#    a
# 0  A
# 1  A
# 0  A
# 1  A

# %%
##merge merges dataset side by side
users = pd.DataFrame({"userid":[1,2,3], "name":["A","B","C"]})
users
# Out:
#    userid name
# 0       1    A
# 1       2    B
# 2       3    C

# %%
megs = pd.DataFrame({"userid":[1,1,2], "msg":["hello","hii","hyy"]})
megs
# Out:
#    userid    msg
# 0       1  hello
# 1       1    hii
# 2       2    hyy

# %%
##conacet here would do here blunder

megs.merge(users,on="userid")
# Out:
#    userid    msg name
# 0       1  hello    A
# 1       1    hii    A
# 2       2    hyy    B

# %%
users.rename(columns={"userid":"id"}, inplace=True)

# %%
users
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
users
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
users.merge(megs,left_on="id", right_on="userid", how="inner")
# Out:
#    id name  userid    msg
# 0   1    A       1  hello
# 1   1    A       1    hii
# 2   2    B       2    hyy

# %%
users.merge(megs,left_on="id", right_on="userid", how="outer")
# Out:
#    id name  userid    msg
# 0   1    A     1.0  hello
# 1   1    A     1.0    hii
# 2   2    B     2.0    hyy
# 3   3    C     NaN    NaN

# %%
users.merge(megs,left_on="id", right_on="userid", how="left") ##keeps the data intact from left boudary
# Out:
#    id name  userid    msg
# 0   1    A     1.0  hello
# 1   1    A     1.0    hii
# 2   2    B     2.0    hyy
# 3   3    C     NaN    NaN

# %%
df
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
df1
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
df = pd.read_csv("movies.csv",index_col=0)
df.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
df1 = pd.read_csv("directors.csv", index_col=0)
df1
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
df.shape
# Out:
# (1465, 11)

# %%
df1.shape
# Out:
# (2349, 3)

# %%
###unqiye directors 
df["director_id"].unique()
# Out:
# array([4762, 4763, 4764, 4765, 4767, 4771, 4772, 4773, 4774, 4775, 4776,
#        4777, 4779, 4780, 4782, 4785, 4786, 4788, 4791, 4793, 4794, 4797,
#        4798, 4799, 4802, 4803, 4804, 4805, 4808, 4809, 4810, 4811, 4812,
#        4813, 4814, 4829, 4831, 4832, 4833, 4838, 4839, 4842, 4845, 4846,
#        4847, 4849, 4854, 4857, 4858, 4859, 4863, 4865, 4866, 4867, 4868,
#        4872, 4873, 4874, 4876, 4880, 4881, 4885, 4886, 4888, 4889, 4890,
#        4892, 4893, 4894, 4900, 4904, 4909, 4913, 4915, 4917, 4918, 4921,
#        4923, 4924, 4925, 4926, 4927, 4930, 4935, 4936, 4945, 4947, 4948,
#        4949, 4955, 4958, 4960, 4964, 4965, 4967, 4974, 4978, 4989, 4991,
#        4993, 4995, 4998, 5002, 5005, 5008, 5009, 5014, 5017, 5024, 5031,
#        5033, 5034, 5035, 5037, 5039, 5047, 5053, 5056, 5059, 5061, 5067,
#        5082, 5087, 5088, 5093, 5096, 5097, 5101, 5105, 5111, 5113, 5115,
#        5116, 5123, 5125, 5130, 5132, 5135, 5140, 5147, 5148, 5152, 5157,
# ...

# %%
df["director_id"].isin(df1["id"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 5       True
#         ...
# 4736    True
# 4743    True
# 4748    True
# 4749    True
# 4768    True
# Name: director_id, Length: 1465, dtype: bool

# %%
##np.all will give me true bonly if all the vaues are true
np.all(df["director_id"].isin(df1["id"]))
# Out:
# np.True_

# %%
data = df.merge(df1, how="left", left_on="director_id", right_on="id")

# %%
data.drop(["director_id", "id_y"], axis=1, inplace=True)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data.describe()
# Out:
#                id_x        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count         year
# count   1465.000000  1465.000000
# mean    1146.396587  2002.615017
# std     1578.077438     8.680141
# min        1.000000  1976.000000
# 25%      216.000000  1998.000000
# 50%      571.000000  2004.000000
# 75%     1387.000000  2009.000000
# ...

# %%
data.describe(include=object) ##non numerical data bhi deta hia, on the basiss of exmple: most frequesnt
# Out:
# C:\Users\chitr\AppData\Local\Temp\ipykernel_7384\3170780047.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include=object) ##non numerical data bhi deta hia, on the basiss of exmple: most frequesnt
#          title month     day     director_name gender
# count     1465  1465    1465              1465   1341
# unique    1465    12       7               199      2
# top     Avatar   Dec  Friday  Steven Spielberg   Male
# freq         1   193     654                26   1309

# %%
data["revenue"]  = data["revenue"]/1000000
data["budget"]  = data["budget"]/1000000

# %%
###Quering Dataframe to fetch the data
data.loc[data["vote_average"] > 8, ["title", "vote_average"]].head()
# Out:
#                                              title  vote_average
# 45                                 The Dark Knight           8.2
# 58                                    Interstellar           8.1
# 59                                       Inception           8.1
# 199  The Lord of the Rings: The Return of the King           8.1
# 383                                     Fight Club           8.3

# %%
data[(data["vote_average"] > 7) & (data["year"] >= 2015)].head()
# Out:
#       id_x     budget  popularity      revenue                    title  \
# 30   43641  190000000         102  15062.49360                Furious 7
# 78   43724  150000000         434   3788.58340       Mad Max: Fury Road
# 106  43773  135000000         100   5329.50503             The Revenant
# 162  43867  108000000         167   6301.61890              The Martian
# 312  44128   75000000          48   1081.45109  The Man from U.N.C.L.E.
#
#      vote_average  vote_count  year month        day  \
# 30            7.3        4176  2015   Apr  Wednesday
# 78            7.2        9427  2015   May  Wednesday
# 106           7.3        6396  2015   Dec     Friday
# 162           7.6        7268  2015   Sep  Wednesday
# 312           7.1        2265  2015   Aug   Thursday
#
#                    director_name gender
# 30                     James Wan   Male
# 78                 George Miller   Male
# 106  Alejandro González Iñárritu   Male
# 162                 Ridley Scott   Male
# ...

# %%
data[data["title"].str.contains("Batman")]
# Out:
#       id_x     budget  popularity     revenue  \
# 5    43606  250000000         155  8732.60194
# 74   43716  150000000         115  3742.18673
# 128  43807  125000000          50  2382.07122
# 184  43896  100000000          48  3365.29144
# 257  44025   80000000          59  2800.00000
# 704  44956   35000000          44  4113.48924
#
#                                   title  vote_average  vote_count  year month  \
# 5    Batman v Superman: Dawn of Justice           5.7        7004  2016   Mar
# 74                        Batman Begins           7.5        7359  2005   Jun
# 128                      Batman & Robin           4.2        1418  1997   Jun
# 184                      Batman Forever           5.2        1498  1995   May
# 257                      Batman Returns           6.6        1673  1992   Jun
# 704                              Batman           7.0        2096  1989   Jun
#
#            day      director_name gender
# 5    Wednesday        Zack Snyder   Male
# ...

# %%
data[data["title"].str.startswith("The")]
# Out:
#        id_x     budget  popularity      revenue  \
# 3     43600  250000000         112  10849.39099
# 9     43610  255000000          49    892.89910
# 11    43612  225000000          53   4196.51413
# 14    43616  250000000         120   9560.19788
# 16    43619  250000000          94   9584.00000
# ...     ...        ...         ...          ...
# 1435  48095     600000          10      0.00000
# 1443  48192     350000          35    294.00000
# 1449  48244     250000           6      0.56825
# 1457  48323          0           5      0.00000
# 1460  48363          0           3      3.21952
#
#                                           title  vote_average  vote_count  \
# 3                         The Dark Knight Rises           7.6        9106
# 9                               The Lone Ranger           5.9        2311
# 11     The Chronicles of Narnia: Prince Caspian           6.3        1630
# 14    The Hobbit: The Battle of the Five Armies           7.1        4760
# ...

# %%
data.sort_values("popularity", ascending=False).head()
# Out:
#       id_x     budget  popularity      revenue  \
# 58   43692  165000000         724   6751.20017
# 78   43724  150000000         434   3788.58340
# 119  43796  140000000         271   6550.11224
# 120  43797  125000000         206   7521.00229
# 45   43662  185000000         187  10045.58444
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
# 45                                     The Dark Knight           8.2
#
#      vote_count  year month        day      director_name gender
# 58        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# 78         9427  2015   May  Wednesday      George Miller   Male
# 119        6985  2003   Jul  Wednesday     Gore Verbinski   Male
# ...

# %%
data.loc[data["director_name"] == "Christopher Nolan", "title"]
# Out:
# 3       The Dark Knight Rises
# 45            The Dark Knight
# 58               Interstellar
# 59                  Inception
# 74              Batman Begins
# 565                  Insomnia
# 641              The Prestige
# 1341                  Memento
# Name: title, dtype: str

# %%
##how to display no of movies by every director
data["director_name"].value_counts()
# Out:
# director_name
# Steven Spielberg       26
# Martin Scorsese        19
# Clint Eastwood         19
# Woody Allen            18
# Ridley Scott           16
#                        ..
# Mike Leigh              5
# Brad Anderson           5
# Michael Polish          5
# Darren Lynn Bousman     5
# Nicole Holofcener       5
# Name: count, Length: 199, dtype: int64

# %%
##higest budgest mivies directed by evey director

data.loc[data["budget"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 3
#       1 ##higest budgest mivies directed by evey director
#       2
# ----> 3 data.loc[data["budget"]]
#
# File c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
# ...

# %%
data.groupby("director_name")["budget"].max() ##this gives a groupby object
# Out:
# director_name
# Adam McKay                     100000000
# Adam Shankman                   80000000
# Alejandro González Iñárritu    135000000
# Alex Proyas                    140000000
# Alexander Payne                 30000000
#                                  ...
# Wes Craven                      40000000
# Wolfgang Petersen              175000000
# Woody Allen                     30000000
# Zack Snyder                    250000000
# Zhang Yimou                     94000000
# Name: budget, Length: 199, dtype: int64

# %%
##which director is most productive director
##-no of movioes, qualit etc
data.groupby("director_name")["title"].count().sort_values(ascending=False)
# Out:
# director_name
# Steven Spielberg    26
# Martin Scorsese     19
# Clint Eastwood      19
# Woody Allen         18
# Robert Rodriguez    16
#                     ..
# Stephen Daldry       5
# Tom Tykwer           5
# Tim Hill             5
# Uwe Boll             5
# Wayne Wang           5
# Name: title, Length: 199, dtype: int64

# %%
##avergae no of movies per year
# active_year = last_workingyear - firstworkingywae

df_agg = data.groupby("director_name")[["year","title"]].aggregate({"year":["min", "max"], "title":["count"]})


##

# %%
df_agg.columns
# Out:
# MultiIndex([( 'year',   'min'),
#             ( 'year',   'max'),
#             ('title', 'count')],
#            )

# %%
df_agg.columns = ["_".join(col) for col in df_agg.columns]

# %%
df_agg.columns
# Out:
# Index(['year_min', 'year_max', 'title_count'], dtype='str')

# %%
df_agg
# Out:
#                              year_min  year_max  title_count
# director_name
# Adam McKay                       2004      2015            6
# Adam Shankman                    2001      2012            8
# Alejandro González Iñárritu      2000      2015            6
# Alex Proyas                      1994      2016            5
# Alexander Payne                  1999      2013            5
# ...                               ...       ...          ...
# Wes Craven                       1984      2011           10
# Wolfgang Petersen                1981      2006            7
# Woody Allen                      1977      2013           18
# Zack Snyder                      2004      2016            7
# Zhang Yimou                      2002      2014            6
#
# [199 rows x 3 columns]

# %%
df_agg.reset_index(inplace=True) ##3rest index stariting with zero

# %%
df_agg["active_yes"] = df_agg["year_max"] - df_agg["year_min"]

# %%
df_agg
# Out:
#                    director_name  year_min  year_max  title_count  active_yes
# 0                     Adam McKay      2004      2015            6          11
# 1                  Adam Shankman      2001      2012            8          11
# 2    Alejandro González Iñárritu      2000      2015            6          15
# 3                    Alex Proyas      1994      2016            5          22
# 4                Alexander Payne      1999      2013            5          14
# ..                           ...       ...       ...          ...         ...
# 194                   Wes Craven      1984      2011           10          27
# 195            Wolfgang Petersen      1981      2006            7          25
# 196                  Woody Allen      1977      2013           18          36
# 197                  Zack Snyder      2004      2016            7          12
# 198                  Zhang Yimou      2002      2014            6          12
#
# [199 rows x 5 columns]

# %%
df_agg["movie_per_yr"] = df_agg["title_count"] / df_agg["active_yes"]

# %%
df_agg
# Out:
#                    director_name  year_min  year_max  title_count  active_yes  \
# 0                     Adam McKay      2004      2015            6          11
# 1                  Adam Shankman      2001      2012            8          11
# 2    Alejandro González Iñárritu      2000      2015            6          15
# 3                    Alex Proyas      1994      2016            5          22
# 4                Alexander Payne      1999      2013            5          14
# ..                           ...       ...       ...          ...         ...
# 194                   Wes Craven      1984      2011           10          27
# 195            Wolfgang Petersen      1981      2006            7          25
# 196                  Woody Allen      1977      2013           18          36
# 197                  Zack Snyder      2004      2016            7          12
# 198                  Zhang Yimou      2002      2014            6          12
#
#      movie_per_yr
# ...

# %%
df_agg.sort_values("movie_per_yr",ascending=False).head()
# Out:
#         director_name  year_min  year_max  title_count  active_yes  \
# 190       Tyler Perry      2006      2013            9           7
# 73    Jason Friedberg      2006      2010            5           4
# 169        Shawn Levy      2002      2014           11          12
# 158  Robert Rodriguez      1992      2014           16          22
# 1       Adam Shankman      2001      2012            8          11
#
#      movie_per_yr
# 190      1.285714
# 73       1.250000
# 169      0.916667
# 158      0.727273
# 1        0.727273

# %%
df_agg.sort_values(["year_min","year_max"], ascending=[True, False])
# Out:
#         director_name  year_min  year_max  title_count  active_yes  \
# 115   Martin Scorsese      1976      2013           19          37
# 148    Richard Donner      1976      2006           11          30
# 170      Sidney Lumet      1976      2006            5          30
# 179  Steven Spielberg      1977      2016           26          39
# 196       Woody Allen      1977      2013           18          36
# ..                ...       ...       ...          ...         ...
# 190       Tyler Perry      2006      2013            9           7
# 73    Jason Friedberg      2006      2010            5           4
# 52   Francis Lawrence      2007      2015            5           8
# 91         Jon M. Chu      2008      2016            5           8
# 130  Nicholas Stoller      2008      2016            5           8
#
#      movie_per_yr
# 115      0.513514
# 148      0.366667
# 170      0.166667
# 179      0.666667
# 196      0.500000
# ..            ...
# 190      1.285714
# ...

# %%
##group based filtering-- filtering rows, but basee on group based property

##filtering all rows (movies ) which are diredcted by high budget directors

##print all the movies od the director who has the high budget

# %%
##find name of directors who have diredted 100m mivid
df_dir_budget =  data.groupby("director_name")["budget"].max().reset_index()

# %%
df_dir_budget
# Out:
#                    director_name  budget
# 0                     Adam McKay   100.0
# 1                  Adam Shankman    80.0
# 2    Alejandro González Iñárritu   135.0
# 3                    Alex Proyas   140.0
# 4                Alexander Payne    30.0
# ..                           ...     ...
# 194                   Wes Craven    40.0
# 195            Wolfgang Petersen   175.0
# 196                  Woody Allen    30.0
# 197                  Zack Snyder   250.0
# 198                  Zhang Yimou    94.0
#
# [199 rows x 2 columns]

# %%
df_dir_budget.loc[df_dir_budget["budget"] >= 100, "director_name"]
# Out:
# 0                       Adam McKay
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 5                   Andrew Adamson
# 10                         Ang Lee
#                   ...
# 187                    Tom Shadyac
# 188                     Tom Tykwer
# 189                     Tony Scott
# 195              Wolfgang Petersen
# 197                    Zack Snyder
# Name: director_name, Length: 85, dtype: str

# %%
data.groupby("director_name").filter(lambda x: x["budget"].max() >= 100)
# Out:
#        id_x  budget  popularity       revenue  \
# 0     43597  237.00         150  2.787965e-08
# 1     43598  300.00         139  9.610000e-09
# 2     43599  245.00         107  8.806746e-09
# 3     43600  250.00         112  1.084939e-08
# 4     43602  258.00         115  8.908716e-09
# ...     ...     ...         ...           ...
# 1450  48267    0.40          33  1.000000e-09
# 1451  48268    0.20          13  4.505922e-11
# 1452  48274    0.00           5  2.611555e-11
# 1458  48335    0.06          27  3.221152e-11
# 1460  48363    0.00           3  3.219520e-12
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data.groupby("director_name").filter(lambda x: x["budget"].max() >= 100)["director_name"].unique()
# Out:
# <StringArray>
# [              'James Cameron',              'Gore Verbinski',
#                   'Sam Mendes',           'Christopher Nolan',
#                    'Sam Raimi',                 'Zack Snyder',
#                 'Bryan Singer',                'Marc Forster',
#               'Andrew Adamson',                'Rob Marshall',
#             'Barry Sonnenfeld',               'Peter Jackson',
#                 'Ridley Scott',                 'Chris Weitz',
#                   'Peter Berg',                  'Tim Burton',
#                 'Brett Ratner',                 'Michael Bay',
#              'Martin Campbell',                         'McG',
#                    'James Wan',                 'Mike Newell',
#           'Guillermo del Toro',            'Steven Spielberg',
#                   'Justin Lin',             'Roland Emmerich',
#              'Robert Zemeckis',             'Lilly Wachowski',
#                  'Jon Favreau',             'Martin Scorsese',
# ...

# %%
##group based trasformation

##Feature/coulumn Transformation -- Budget/ Revenue dollars -> m dollars

# %%
##asses every movie wrt to director avergare budget
# def Subtract_avg(x):
#     x["additional_budget"] = x["budget"] - x["budget"].mean()

# def inspect(x):
#     print(x)
#     print(type(x))
#     raise


data.groupby("director_name").transform(inspect)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 13
#       9
#      10 def Subtract_avg(x):
#      11     return x - x.mean()
#      12
# ---> 13 data.groupby("director_name").transform(Subtract_avg)
#
# File c:\Users\chitr\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\groupby\generic.py:2792, in DataFrameGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    2646 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
#    2647     """
#    2648     Call function producing a same-indexed DataFrame on each group.
#    2649
#    (...)   2790     5  5  9
#    2791     """
# -> 2792     return self._transform(
#    2793         func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#    2794     )
#
# ...

# %%
def Subtract_avg(x):
    return x - x.mean()

##transform works with seriess


data["additional_budget"] = data.groupby("director_name")["budget"].transform(Subtract_avg)
data
# Out:
#        id_x   budget  popularity       revenue  \
# 0     43597  237.000         150  2.787965e-08
# 1     43598  300.000         139  9.610000e-09
# 2     43599  245.000         107  8.806746e-09
# 3     43600  250.000         112  1.084939e-08
# 4     43602  258.000         115  8.908716e-09
# ...     ...      ...         ...           ...
# 1460  48363    0.000           3  3.219520e-12
# 1461  48370    0.027          19  3.151130e-11
# 1462  48375    0.000           7  0.000000e+00
# 1463  48376    0.000           3  0.000000e+00
# 1464  48395    0.220          14  2.040920e-11
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
##for ba movie, if it was risky for a director or not---whose buget was even higher than average revenue of the moviee director by same director

def func(x):
    x["risky"] = x["budget"] - x["revenue"].mean() >= 0
    return x

    
df_risky =   data.groupby("director_name").apply(func)

# %%
df_risky.loc[df_risky["risky"] == True]
# Out:
#                     id_x     budget  popularity       revenue  \
# director_name
# Adam McKay    176  43882  100.00000          24  1.704329e-09
#               323  44151   72.50000          12  1.629662e-09
#               366  44236   65.00000          22  1.281076e-09
#               505  44503   50.00000          38  1.736490e-09
#               839  45301   28.00000          57  1.333465e-09
# ...                  ...        ...         ...           ...
# Zack Snyder   396  44284   65.00000          65  4.226104e-09
#               842  45304   28.00000          44  1.023564e-09
# Zhang Yimou   192  43914   94.00000          12  9.531143e-10
#               590  44692    0.00011           9  0.000000e+00
#               604  44733   31.00000          23  1.773944e-09
#
#                                                          title  vote_average  \
# director_name
# Adam McKay    176                               The Other Guys           6.1
# ...

# %%
##aggregate -- for all rows, group based
##filering -- values in rows, based same group based properties
## transformation - values in rows ,or groupt based properties do that transformation
